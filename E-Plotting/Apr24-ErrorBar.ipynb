# %% [markdown]
# ### 4.1 Energy benchmarking & breakdown
# * No need for alpha-value change
# * Color control

# %%
from ReIDF_plot import overview_annual
parent_folders = [
    '2025-Apr15'
]

metered_csv = 'Metering.csv'
start_date = '2023-01-01'
end_date = '2024-01-01'
area = 8894
legend_mapping = {
    '2025-Apr15': 'Simulation (9 simulations)',
}

overview_annual(parent_folders, metered_csv, start_date, end_date, area, legend_mapping, verbose=False)

# %%
from ReIDF_plot import breakdown_annual

breakdown_annual(parent_folders, metered_csv, start_date, end_date, area, legend_mapping, verbose=False)

# %%
from ReIDF_plot import breakdown_monthly

breakdown_monthly(parent_folders, metered_csv, start_date, end_date, area, legend_mapping, verbose=False)

# %% [markdown]
# ### 4.2 Energy Profiling

# %%
from ReIDF_plot import profiling_subhourly

parent_folder = '2025-Apr15'
area = 8894
energy_columns = ['DistrictHeatingWater:Facility [J](Hourly)']
metered_csv = 'Metering.csv'
profiling_subhourly(parent_folder, start_date, end_date, energy_columns, combined=True, alpha=0.75, area = 8894,
                       metered_csv=metered_csv, metered_column='Main Heating', num_xticks=5, verbose=False)

# %% [markdown]
# # References

# %% [markdown]
# [1]
